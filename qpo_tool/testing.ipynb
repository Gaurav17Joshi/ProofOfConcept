# %%
from prior import get_prior

import jax
jax.config.update("jax_enable_x64", True)
import jax.numpy as jnp
import numpy as np
import matplotlib.pyplot as plt
import tinygp
from tinygp import GaussianProcess, kernels
from stingray import Lightcurve
jax.config.update("jax_enable_x64", True)
import functools
# Out:
# INFO[2023-06-12 10:59:49,463]: Remote TPU is not linked into jax; skipping remote TPU.
# INFO[2023-06-12 10:59:49,464]: Unable to initialize backend 'tpu_driver': Could not initialize backend 'tpu_driver'
# INFO[2023-06-12 10:59:49,464]: Unable to initialize backend 'cuda': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO[2023-06-12 10:59:49,464]: Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO[2023-06-12 10:59:49,465]: Unable to initialize backend 'tpu': module 'jaxlib.xla_extension' has no attribute 'get_tpu_client'
# INFO[2023-06-12 10:59:49,466]: Unable to initialize backend 'plugin': xla_extension has no attributes named get_plugin_device_client. Compile TensorFlow with //tensorflow/compiler/xla/python:enable_plugin_device set to true (defaults to false) to enable this.
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/stingray/utils.py:25: UserWarning: pyfftw not installed. Using standard scipy fft
#   warnings.warn("pyfftw not installed. Using standard scipy fft")
# INFO[2023-06-12 10:59:51,142]: NumExpr defaulting to 8 threads.

# %%
"""
MAKING THE DATA
"""

Times = np.linspace(0,1,256)

def gaussian(t, mean_params):
    return mean_params["A"] * jnp.exp(-((t - mean_params["t0"])**2)/(2*(mean_params["sig"]**2)))

# Build Gp
def build_gp(kernel_params, mean_params, t, kernel_type, mean_type = "gaussian"):
    if kernel_type == "QPO_plus_RN":
        kernel = kernels.quasisep.Exp(
                scale = 1/kernel_params["crn"], sigma = (kernel_params["arn"])**0.5) + kernels.quasisep.Celerite(
                a = kernel_params["aqpo"], b = 0.0, c = kernel_params["cqpo"], d = 2*jnp.pi*kernel_params["freq"])
    elif kernel_type == "RN":
        kernel = kernels.quasisep.Exp(
                scale = 1/kernel_params["crn"], sigma = (kernel_params["arn"])**0.5)
    
    # Using partial to make the mean so that it only takes the time value
    if mean_type == "gaussian":
        mean = functools.partial(gaussian, mean_params = mean_params)
        return tinygp.GaussianProcess( kernel, t, mean=mean)
    elif mean_type == "constant":
        mean = mean_params
        return tinygp.GaussianProcess( kernel, t)

hqpoparams = {
    "arn" : jnp.exp(1.0),    "crn" : jnp.exp(1.0),
    "aqpo": jnp.exp(-0.4),    "cqpo": jnp.exp(1),    "freq": 20,
}

hqpokernel = kernels.quasisep.Exp(
    scale = 1/hqpoparams["crn"], sigma = (hqpoparams["arn"])**0.5) + kernels.quasisep.Celerite(
        a = hqpoparams["aqpo"], b = 0.0, c = hqpoparams["cqpo"], d = 2*jnp.pi*hqpoparams["freq"])

mean_params = {
    "A" : 3,    "t0" : 0.5,    "sig" : 0.2,
}

hqpogp = build_gp(hqpoparams, mean_params, Times, kernel_type = "QPO_plus_RN")

lightcurve_vals = hqpogp.sample(jax.random.PRNGKey(4))
lightcurve = Lightcurve(Times, lightcurve_vals)
# Out:
# INFO[2023-06-12 10:59:56,379]: Checking if light curve is well behaved. This can take time, so if you are sure it is already sorted, specify skip_checks=True at light curve creation.
# INFO[2023-06-12 10:59:56,379]: Checking if light curve is sorted.
# INFO[2023-06-12 10:59:56,380]: Computing the bin time ``dt``. This can take time. If you know the bin time, please specify it at light curve creation

# %%
"""
GETTING RESULTS
"""

parameters = {
                # "kernel_type" : "qpo_plus_red_noise",
                # "mean_type" : "gaussian",
                "Times" : Times,
                "counts" : lightcurve_vals,
                "diag" : 0.1,
                "arn" : jnp.exp(1.0),    "crn" : jnp.exp(1.0),
                "aqpo": jnp.exp(-0.4),    "cqpo": jnp.exp(1),    "freq": 20,
                "A" : 3,    "t0" : 0.5,    "sig" : 0.2,
}

from GP import GP

model_type = ("QPO_plus_RN", "gaussian")

gp = GP(Lc = lightcurve, Model_type = model_type, Model_params = parameters)

# %%
print(gp.maingp)
print(gp.maingp.kernel)
print(len(gp.maingp.X))
print(type(gp.maingp.X))
# Out:
# <tinygp.gp.GaussianProcess object at 0x166805610>
# Sum(kernel1=Exp(scale=Array(0.36787944, dtype=float64, weak_type=True), sigma=Array(1.64872127, dtype=float64, weak_type=True)), kernel2=Celerite(a=Array(0.67032005, dtype=float64, weak_type=True), b=0.0, c=Array(2.71828183, dtype=float64, weak_type=True), d=125.66370614359172))
# 256
# <class 'numpy.ndarray'>

# %%
gp.get_logprob()
# Out:
# Array(-122.0715603, dtype=float64)

# %%
# Xtest = jnp.linspace(0,1,512)
gp.plot_originalgp(sample_no = 5)

# %%
gp.plot_gp(X_test= Times, sample_no = 4)

# %%
from GP import GPResult

gpresult = GPResult(gp, prior_type = ("QPO_plus_RN", "gaussian"), prior_parameters=parameters)

# %%
gpresult.run_sampling()
# Out:
# <function get_prior.<locals>.QPOprior_model at 0x16ec23790>
# arn	() -> () <class 'numpy.float64'>
# crn	() -> () <class 'numpy.float64'>
# aqpo	() -> () <class 'numpy.float64'>
# cqpo	() -> () <class 'numpy.float64'>
# freq	() -> () <class 'numpy.float64'>
# A	() -> () <class 'numpy.float64'>
# t0	() -> () <class 'numpy.float64'>
# sig	() -> () <class 'numpy.float64'>
# <PjitFunction of <function get_likelihood.<locals>.QPOlog_likelihood at 0x2a81abd30>>
# hi
# <tinygp.gp.GaussianProcess object at 0x2a8206a90>
# Sum(kernel1=Exp(scale=Traced<ShapedArray(float64[])>with<DynamicJaxprTrace(level=3/0)>, sigma=Traced<ShapedArray(float64[])>with<DynamicJaxprTrace(level=3/0)>), kernel2=Celerite(a=Traced<ShapedArray(float64[])>with<DynamicJaxprTrace(level=3/0)>, b=0.0, c=Traced<ShapedArray(float64[])>with<DynamicJaxprTrace(level=3/0)>, d=Traced<ShapedArray(float64[])>with<DynamicJaxprTrace(level=3/0)>))
# 256
# <class 'numpy.ndarray'>
# log_likelihood Traced<ShapedArray(float64[])>with<DynamicJaxprTrace(level=3/0)>
# INFO[2023-06-12 11:01:58,838]: Sanity check...
# INFO[2023-06-12 11:01:58,963]: Sanity check passed
# hi
# <tinygp.gp.GaussianProcess object at 0x2a8541f70>
# Sum(kernel1=Exp(scale=Traced<ShapedArray(float64[])>with<DynamicJaxprTrace(level=5/1)>, sigma=Traced<ShapedArray(float64[])>with<DynamicJaxprTrace(level=5/1)>), kernel2=Celerite(a=Traced<ShapedArray(float64[])>with<DynamicJaxprTrace(level=5/1)>, b=0.0, c=Traced<ShapedArray(float64[])>with<DynamicJaxprTrace(level=5/1)>, d=Traced<ShapedArray(float64[])>with<DynamicJaxprTrace(level=5/1)>))
# 256
# <class 'numpy.ndarray'>
# log_likelihood Traced<ShapedArray(float64[])>with<DynamicJaxprTrace(level=5/1)>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/gaurav/Desktop/Open_Source/ProofOfConcept/qpo_tool/testing.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/gaurav/Desktop/Open_Source/ProofOfConcept/qpo_tool/testing.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> gpresult.run_sampling()
#
# File ~/Desktop/Open_Source/ProofOfConcept/qpo_tool/GP.py:353, in GPResult.run_sampling(self)
#     350 NSmodel.sanity_check(random.PRNGKey(10), S = 100)
#     352 self.Exact_ns = ExactNestedSampler(NSmodel, num_live_points= 500, max_samples= 1e4)
# --> 353 Termination_reason, State = self.Exact_ns(random.PRNGKey(42), term_cond=TerminationCondition(live_evidence_frac=1e-4))
#     354 self.Results = self.Exact_ns.to_results(State, Termination_reason)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/jaxns/nested_sampler.py:400, in ExactNestedSampler.__call__(self, key, term_cond, init_state, live_points)
#     397 if isinstance(key, core.Tracer):
#     398     raise RuntimeError("Tracer detected, but expected imperative context.")
# --> 400 termination_reason, state = self.approximate_sampler(key=key, term_cond=term_cond, init_state=init_state,
#     401                                                      live_points=live_points)
#     402 state = self.improvement(state=state)
#     404 return termination_reason, state
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/jaxns/nested_sampler.py:313, in ApproximateNestedSampler.__call__(self, key, term_cond, init_state, live_points)
#     310     term_cond = term_cond._replace(max_samples=jnp.minimum(self.max_samples, term_cond.max_samples))
#     311 if init_state is None:
#     312     # We create fresh live points and state
# --> 313     termination_reason, state = self.fresh_run(key=key, term_cond=term_cond)
#     314 else:
#     315     if live_points is None:
#     316         # We create a fresh set of live points from -inf contour and run on top of init_state
#
#     [... skipping hidden 12 frame]
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/jaxns/nested_sampler.py:253, in ApproximateNestedSampler.fresh_run(self, key, term_cond)
#     242 """
#     243 Creates a new initial state and live points from -inf contour and samples until termination.
#     244
#    (...)
#     250     termination reason, and state
#     251 """
#     252 state, live_points = self.initialise(key=key)
# --> 253 return self.approximate_shrinkage(state=state, live_points=live_points, term_cond=term_cond)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/jaxns/nested_sampler.py:234, in ApproximateNestedSampler.approximate_shrinkage(self, state, live_points, term_cond)
#     232 state, live_points = self.static_uniform(state=state, live_points=live_points)
#     233 # Low accuracy sampling
# --> 234 termination_reason, state, live_points = self.static_slice(state=state,
#     235                                                            live_points=live_points,
#     236                                                            termination_cond=term_cond)
#     237 state = collect_samples(state=state, new_reservoir=live_points.reservoir)
#     238 return termination_reason, state
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/jaxns/static_slice.py:199, in StaticSlice.__call__(self, state, live_points, termination_cond)
#     191 chunked_live_points = add_chunk_dim(live_points, self.num_parallel_samplers)
#     193 parallel_ns = pmap(lambda live_points: self._single_thread_ns(
#     194     state=state,
#     195     live_points=live_points,
#     196     termination_cond=termination_cond
#     197 ), axis_name='i')
# --> 199 chunked_termination_reason, chunked_state, chunked_live_points = parallel_ns(chunked_live_points)
#     201 termination_reason, state = tree_map(lambda x: x[0], (chunked_termination_reason, chunked_state))
#     202 live_points = remove_chunk_dim(chunked_live_points)
#
#     [... skipping hidden 6 frame]
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/jaxns/static_slice.py:193, in StaticSlice.__call__.<locals>.<lambda>(live_points)
#     187     raise ValueError(
#     188         f"live points reservoir is the wrong size. "
#     189         f"Got {live_points.reservoir.log_L.size} but expected {self.num_live_points}.")
#     191 chunked_live_points = add_chunk_dim(live_points, self.num_parallel_samplers)
# --> 193 parallel_ns = pmap(lambda live_points: self._single_thread_ns(
#     194     state=state,
#     195     live_points=live_points,
#     196     termination_cond=termination_cond
#     197 ), axis_name='i')
#     199 chunked_termination_reason, chunked_state, chunked_live_points = parallel_ns(chunked_live_points)
#     201 termination_reason, state = tree_map(lambda x: x[0], (chunked_termination_reason, chunked_state))
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/jaxns/static_slice.py:161, in StaticSlice._single_thread_ns(self, state, live_points, termination_cond)
#     151     done, termination_reason = determine_termination(
#     152         term_cond=termination_cond,
#     153         sample_collection=new_state.sample_collection,
#     154         evidence_calculation=evidence_calculation,
#     155         live_points=live_points
#     156     )
#     158     return CarryType(done=done, termination_reason=termination_reason, state=new_state,
#     159                      live_points=live_points)
# --> 161 output_carry = while_loop(
#     162     lambda body_state: jnp.bitwise_not(body_state[0]),
#     163     body,
#     164     CarryType(done=jnp.asarray(False, jnp.bool_),
#     165               termination_reason=jnp.asarray(0, int_type), state=state, live_points=live_points)
#     166 )
#     168 return output_carry.termination_reason, output_carry.state, output_carry.live_points
#
#     [... skipping hidden 9 frame]
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/jaxns/static_slice.py:135, in StaticSlice._single_thread_ns.<locals>.body(body_state)
#     131 state = body_state.state._replace(key=key)
#     133 preprocess_data = self.slice_sampler.preprocess(state)
# --> 135 (dead_reservoir, live_points) = self._single_live_point_shrink(
#     136     key=sample_key,
#     137     live_points=body_state.live_points,
#     138     num_slices=self.num_slices,
#     139     preprocess_data=preprocess_data
#     140 )
#     142 all_dead_reservoir: Reservoir = remove_chunk_dim(all_gather(dead_reservoir, 'i'))
#     144 # update the state with sampled points from last round
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/jaxns/static_slice.py:115, in StaticSlice._single_live_point_shrink(self, key, live_points, num_slices, preprocess_data)
#     111     live_points = carry.live_points._replace(reservoir=live_points_reservoir)
#     113     return CarryType(key, live_points), dead_point
# --> 115 (_, live_points), dead_reservoir = scan(body,
#     116                                         CarryType(key, live_points),
#     117                                         live_points.reservoir.log_L)
#     118 return (dead_reservoir, live_points)
#
#     [... skipping hidden 9 frame]
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/jaxns/static_slice.py:103, in StaticSlice._single_live_point_shrink.<locals>.body(***failed resolving arguments***)
#      98 key, seed_key, sample_key = random.split(carry.key, 3)
#     100 seed_point = self.slice_sampler.get_seed_point(key=seed_key,
#     101                                                live_points=carry.live_points,
#     102                                                log_L_constraint=log_L_contour)
# --> 103 sample = self.slice_sampler.get_sample(key=sample_key,
#     104                                        seed_point=seed_point,
#     105                                        log_L_constraint=log_L_contour,
#     106                                        num_slices=num_slices,
#     107                                        preprocess_data=preprocess_data)
#     109 live_points_reservoir = tree_map(lambda old, update: old.at[idx_min].set(update),
#     110                                  carry.live_points.reservoir, Reservoir(*sample))
#     111 live_points = carry.live_points._replace(reservoir=live_points_reservoir)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/jaxns/slice_sampler.py:328, in UniDimSliceSampler.get_sample(self, key, seed_point, log_L_constraint, num_slices, preprocess_data)
#     325     (proposal_state, _) = body_state
#     326     return jnp.less(proposal_state.proposal_count, num_slices)
# --> 328 (proposal_state, log_L) = while_loop(slice_sampler_cond,
#     329                                      slice_sampler_body,
#     330                                      (init_proposal_state, -jnp.inf))
#     331 # passthrough when num_slices==0
#     332 pass_through = num_slices == jnp.zeros_like(num_slices)
#
#     [... skipping hidden 2 frame]
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/jax/_src/lax/control_flow/common.py:108, in _check_tree_and_avals(what, tree1, avals1, tree2, avals2)
#     105 if not all(map(core.typematch, avals1, avals2)):
#     106   diff = tree_map(_show_diff, tree_unflatten(tree1, avals1),
#     107                   tree_unflatten(tree2, avals2))
# --> 108   raise TypeError(f"{what} must have identical types, got\n{diff}.")
#
# TypeError: body_fun output and input must have identical types, got
# (UniDimProposalState(key='ShapedArray(uint32[2])', process_step='ShapedArray(int32[])', proposal_count='ShapedArray(int32[])', num_likelihood_evaluations='ShapedArray(int32[])', point_U0='ShapedArray(float32[8])', log_L0='ShapedArray(float32[])', direction='ShapedArray(float32[8])', left='DIFFERENT ShapedArray(float64[]) vs. ShapedArray(float32[])', right='DIFFERENT ShapedArray(float64[]) vs. ShapedArray(float32[])', point_U='ShapedArray(float32[8])', t='ShapedArray(float32[])', log_L_constraint='ShapedArray(float64[])'), 'ShapedArray(float32[])').
